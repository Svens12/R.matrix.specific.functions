# %%
A<-matrix(1:9,3,3)

# %%
A
# Out:
#      [,1] [,2] [,3]
# [1,] 1    4    7
# [2,] 2    5    8
# [3,] 3    6    9

# %%
rowSums(A)
# Out:
# [1] 12 15 18

# %%
colSums(A)
# Out:
# [1]  6 15 24

# %%
rowMeans(A)
# Out:
# [1] 4 5 6

# %%
colMeans(A)
# Out:
# [1] 2 5 8

# %%
apply(A,1,sum)
# Out:
# [1] 12 15 18

# %%
apply(A,2,sum)
# Out:
# [1]  6 15 24
